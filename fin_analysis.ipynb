# %% [markdown]
# ## Получение котировок акций при помощи Python

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

data = pd.DataFrame(columns=tickers_list)

for ticker in tickers_list:
    data[ticker] = yf.download(ticker, '2020-01-01', '2023-01-01')['Adj Close']

data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  AAPL         WMT         IBM         MU          BA  \
# Date
# 2020-01-02  73.449402  112.910889  110.232506  54.719234  331.348572
# 2020-01-03  72.735313  111.914101  109.353386  53.869652  330.791901
# 2020-01-06  73.314896  111.686287  109.158020  52.921272  331.766083
# 2020-01-07  72.970078  110.651535  109.231285  57.564362  335.285156
# 2020-01-08  74.143913  110.271805  110.142975  56.823444  329.410095
#
#                    AXP
# Date
# 2020-01-02  120.207718
# 2020-01-03  119.013756
# 2020-01-06  118.497971
# 2020-01-07  117.877113
# 2020-01-08  119.911629

# %%
((data.pct_change()+1).cumprod()).plot(figsize=(15, 7))

plt.legend()
plt.title('Adjusted close price', fontsize=16)

plt.ylabel('Price')
plt.xlabel('Year')

plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()
